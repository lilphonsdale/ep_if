# %%
import pandas as pd

# %%
results = "ELA Results.csv"
results_df = pd.DataFrame(pd.read_csv(results))
new_header = results_df.iloc[0]
results_df = results_df[1:]
results_df.columns = new_header
results_df.head()
# Out:
# 0 School ID  Year                Test Name # Students Tested NaN  \
# 1    400009  2017  Combined ELA Grades 3-8               179 NaN
# 2    400011  2017  Combined ELA Grades 3-8               297 NaN
# 3    400017  2017  Combined ELA Grades 3-8               524 NaN
# 4    400021  2017  Combined ELA Grades 3-8               330 NaN
# 5    400023  2017  Combined ELA Grades 3-8               268 NaN
#
# 0 Overall ELA Mean Scale Score % Did Not Meet % Partially Met % Approached  \
# 1                                       19.0%           31.3%        22.9%
# 2                                        7.7%           12.1%        38.0%
# 3                                       35.9%           28.2%        24.0%
# 4                                       27.9%           27.0%        28.2%
# 5                                        9.3%           21.6%        32.1%
#
# 0  % Met  ... % Met or Exceeded Writing Mean Scale Score NaN  \
# ...

# %%
pilot_schools = [
    "610534",
    "609880",
    "610066",
    "610082",
    "610182" 
]

# %%
pilot_participants = results_df[results_df['School ID'].isin(pilot_schools)]
pilot_participants = pilot_participants[results_df['Test Name']=="ELA/Literacy Grade 5"]
pilot_participants_2017 = pilot_participants[results_df['Year']=="2017"]
pilot_participants_2017
# Out:
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0    School ID  Year             Test Name # Students Tested NaN  \
# 1544    609880  2017  ELA/Literacy Grade 5                29 NaN
# 1673    610066  2017  ELA/Literacy Grade 5                27 NaN
# 1683    610082  2017  ELA/Literacy Grade 5               102 NaN
# 1757    610182  2017  ELA/Literacy Grade 5                24 NaN
# 1858    610534  2017  ELA/Literacy Grade 5                62 NaN
# 1859    610534  2017  ELA/Literacy Grade 5                62 NaN
#
# ...

# %%
pilot_participants_2017["Overall ELA Mean Scale Score"].astype(int).describe()
# Out:
# count      6.000000
# mean     785.000000
# std       11.489125
# min      768.000000
# 25%      777.000000
# 50%      789.000000
# 75%      794.250000
# max      795.000000
# Name: Overall ELA Mean Scale Score, dtype: float64

# %%
pilot_participants = results_df[results_df['School ID'].isin(pilot_schools)]
pilot_participants = pilot_participants[results_df['Test Name']=="ELA/Literacy Grade 5"]
pilot_participants_2016 = pilot_participants[results_df['Year']=="2016"]
pilot_participants_2016
# Out:
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0    School ID  Year             Test Name # Students Tested NaN  \
# 4926    609880  2016  ELA/Literacy Grade 5                30 NaN
# 4927    609880  2016  ELA/Literacy Grade 5                30 NaN
# 5057    610066  2016  ELA/Literacy Grade 5                29 NaN
# 5067    610082  2016  ELA/Literacy Grade 5               112 NaN
# 5143    610182  2016  ELA/Literacy Grade 5                28 NaN
# 5244    610534  2016  ELA/Literacy Grade 5                58 NaN
#
# ...

# %%
growth = pd.merge(left=pilot_participants_2017, right=pilot_participants_2016,how='right',on='School ID')
growth = growth[["School ID","Overall ELA Mean Scale Score_x","Overall ELA Mean Scale Score_y"]]
growth
# Out:
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nan_y', 'nan_x'} in the result is deprecated and will raise a MergeError in a future version.
#   """Entry point for launching an IPython kernel.
# 0 School ID Overall ELA Mean Scale Score_x Overall ELA Mean Scale Score_y
# 0    609880                            792                            791
# 1    609880                            792                            791
# 2    610066                            786                            772
# 3    610082                            774                            768
# 4    610182                            768                            764
# 5    610534                            795                            793
# 6    610534                            795                            793

# %%
growth = growth.astype(int)
growth.dtypes
# Out:
# 0
# School ID                         int64
# Overall ELA Mean Scale Score_x    int64
# Overall ELA Mean Scale Score_y    int64
# dtype: object

# %%
for i in growth:
    growth["change"] = growth["Overall ELA Mean Scale Score_x"] - growth["Overall ELA Mean Scale Score_y"]
    growth["percent_change"] = ((growth["Overall ELA Mean Scale Score_x"] - growth["Overall ELA Mean Scale Score_y"])/growth["Overall ELA Mean Scale Score_y"])*100

growth.sort_values(by="percent_change", ascending=False)
# Out:
# 0  School ID  Overall ELA Mean Scale Score_x  Overall ELA Mean Scale Score_y  \
# 2     610066                             786                             772
# 3     610082                             774                             768
# 4     610182                             768                             764
# 5     610534                             795                             793
# 6     610534                             795                             793
# 0     609880                             792                             791
# 1     609880                             792                             791
#
# 0  change  percent_change
# 2      14        1.813472
# 3       6        0.781250
# 4       4        0.523560
# 5       2        0.252207
# 6       2        0.252207
# 0       1        0.126422
# 1       1        0.126422

# %%
non_pilot = results_df[results_df['School ID'].isin(pilot_schools) == False]
non_pilot = non_pilot[results_df['Test Name']=="ELA/Literacy Grade 5"]
non_pilot_2017 = non_pilot[results_df['Year']=="2017"]
non_pilot_2017
# Out:
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/oaklandsveryown/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0    School ID  Year             Test Name # Students Tested NaN  \
# 1412    400009  2017  ELA/Literacy Grade 5                30 NaN
# 1413    400011  2017  ELA/Literacy Grade 5                49 NaN
# 1414    400021  2017  ELA/Literacy Grade 5                55 NaN
# 1415    400023  2017  ELA/Literacy Grade 5                55 NaN
# 1416    400024  2017  ELA/Literacy Grade 5                65 NaN
# ...        ...   ...                   ...               ...  ..
# 1863    610544  2017  ELA/Literacy Grade 5               111 NaN
# ...

# %%
non_pilot_2017["Overall ELA Mean Scale Score"].astype(int).describe()
# Out:
# count    450.000000
# mean     725.215556
# std       16.140950
# min      684.000000
# 25%      714.000000
# 50%      723.000000
# 75%      734.000000
# max      791.000000
# Name: Overall ELA Mean Scale Score, dtype: float64
